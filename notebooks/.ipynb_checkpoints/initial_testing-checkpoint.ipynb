# %% [markdown]
# # Initial Work into Multi-Armed Bandits
#
# ## Explore-First

# %%
import sys
import os

module_path = os.path.abspath(os.path.join('../'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from src.bandits import RandomizedStochasticBandit
from src.agents import ExploreExploit, EpsGreedy
from src.arms import UniformArm

import numpy as np

import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline

mpl.rcParams['figure.dpi'] = 300

# %%
K = 10
T = 1000

arm_factory = UniformArm.factory()
bandit = RandomizedStochasticBandit(5, arm_factory)
agent = ExploreExploit(bandit, K, T)
# Out:
# Multi-Armed Bandit Problem
#  K=5
#  mu_star = 0.7130961987835875
#  a_star  = 3
#
# Uniform Arm mu 0.31345708964231517, R in [0.0028159911630617485, 0.6240981881215686]
# Uniform Arm mu 0.4230385330379603, R in [0.09428884940797833, 0.7517882166679423]
# Uniform Arm mu 0.5239014194245434, R in [0.2130097174598416, 0.8347931213892452]
# Uniform Arm mu 0.7130961987835875, R in [0.43063521172913527, 0.9955571858380399]
# Uniform Arm mu 0.5472334807619578, R in [0.321006116615717, 0.7734608449081986]

# %%
rs = []
crs = []
ats = []

while not agent.terminated():
    reward, cum_reward, a_t = agent.step()
    rs.append(reward)
    crs.append(cum_reward)
    ats.append(a_t)

# %%
plt.figure(figsize=(10, 10))
plt.subplot(3, 1, 1)
plt.plot(rs)
plt.title("Explore-Exploit")
plt.xlabel("Step")
plt.ylabel("$r_t$")

plt.subplot(3, 1, 2)
plt.plot(crs)
plt.xlabel("Step")
plt.ylabel("Real. Regret")

plt.subplot(3, 1, 3)
plt.plot(ats)
plt.xlabel("Step");
plt.ylabel("Action Taken");

# %% [markdown]
# ## Epsilon Greedy

# %%
eps = 0.1
T = 1000

bandit = RandomizedStochasticBandit(5, arm_factory)
agent = EpsGreedy(bandit, eps, T)
# Out:
# Multi-Armed Bandit Problem
#  K=5
#  mu_star = 0.46699140787607185
#  a_star  = 4
#
# Uniform Arm mu 0.4642907507178684, R in [0.08038356853766965, 0.8481979328980671]
# Uniform Arm mu 0.3903172110155768, R in [0.21096606353445196, 0.5696683584967016]
# Uniform Arm mu 0.4055237018001462, R in [0.4013018536024698, 0.40974554999782253]
# Uniform Arm mu 0.09082075379668184, R in [0.07843278290246758, 0.10320872469089609]
# Uniform Arm mu 0.46699140787607185, R in [0.37948694864256843, 0.5544958671095753]

# %%
rs = []
crs = []
ats = []

while not agent.terminated():
    reward, cum_reward, a_t = agent.step()
    rs.append(reward)
    crs.append(cum_reward)
    ats.append(a_t)
    
plt.figure(figsize=(10, 10))
plt.subplot(3, 1, 1)
plt.plot(rs)
plt.title("Explore-Exploit")
plt.xlabel("Step")
plt.ylabel("$r_t$")

plt.subplot(3, 1, 2)
plt.plot(crs)
plt.xlabel("Step")
plt.ylabel("Real. Regret")

plt.subplot(3, 1, 3)
plt.plot(ats)
plt.xlabel("Step");
plt.ylabel("Action Taken");
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-115bfb72edec> in <module>
#       4
#       5 while not agent.terminated():
# ----> 6     reward, cum_reward, a_t = agent.step()
#       7     rs.append(reward)
#       8     crs.append(cum_reward)
#
# ~/workspace/AIMS-CDT/bandits/src/agents.py in step(self)
#      48
#      49     def step(self):
# ---> 50         p = np.random.bernoulli(1, self.eps)
#      51
#      52         if self.terminated():
#
# AttributeError: module 'numpy.random' has no attribute 'bernoulli'
