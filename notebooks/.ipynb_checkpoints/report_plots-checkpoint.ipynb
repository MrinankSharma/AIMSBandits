# %%
import sys
import os

module_path = os.path.abspath(os.path.join('../'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from src.bandits import RandomizedStochasticBandit, BaseStochasticBandit
from src.agents import ExploreExploit, OptimalEpsGreedy, UCB, Thompson
from src.arms import UniformArm, GaussianArm, BernoulliArm

import numpy as np

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %matplotlib inline
mpl.rcParams['figure.dpi'] = 300

# %%
K = 5

# prior 
alpha = 1
beta = 1

arm_factory = BernoulliArm.factory(alpha, beta)
arms = [arm_factory() for i in range(K)]
arm_means = [arm.mu for arm in arms]
bandit = BaseStochasticBandit(arms)
# Out:
# Multi-Armed Bandit Problem
#  K=5
#  mu_star = 0.9945481460247728
#  a_star  = 4
#
# Bernoulli Arm mu 0.811039112305842,
# Posterior is 1, 1
#
# Bernoulli Arm mu 0.6696211148110218,
# Posterior is 1, 1
#
# Bernoulli Arm mu 0.17874690347285727,
# Posterior is 1, 1
#
# Bernoulli Arm mu 0.8927806374311209,
# Posterior is 1, 1
#
# Bernoulli Arm mu 0.9945481460247728,
# Posterior is 1, 1

# %%
N_seeds = 10
T = 10000

agent_classes = [Thompson, UCB, lambda x, y: ExploreExploit(x, 1, y, opt=True), lambda x, y: OptimalEpsGreedy(x, 0.01, T)]
agent_names = ["Thompson", "UCB", "Explore-First", "$\epsilon$-Greedy"]
agent_mats = [np.zeros((N_seeds, T+1)) for i in range(len(agent_classes))]

def run_agent(agent):
    crs = []

    while not agent.terminated():
        reward, cum_reward, a_t = agent.step()
        crs.append(cum_reward)
    
    return np.array(crs)


for i, agent_class in enumerate(agent_classes):
    for seed in range(N_seeds):
        bandit.reset(False)
        agent = agent_class(bandit, T)
        agent_mats[i][seed, :] = run_agent(agent)

# %%
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
sns.regplot(x = np.arange(1, K+1), y=sorted(arm_means), fit_reg=False)
plt.xlabel("Arm Index");
plt.ylabel("$\mu_i$");

plt.subplot(1, 2, 2)
xs = np.arange(0, T+1)
colors = ['b', 'r', 'g', 'k']
ax = plt.gca()

for indx, agent_mat in enumerate(agent_mats):
    r_mat = agent_mats[indx]
    mu = np.mean(r_mat, axis=0)
    std = np.std(r_mat, axis=0)
    
    plt.fill_between(xs, mu - std, mu + std, alpha=0.25, color = colors[indx])
    plt.plot(mu, color = colors[indx], label=f"{agent_names[indx]}")
    ax.set_yscale('log')
    ax.set_xscale('log')
    ax.set_xlabel('Rounds')
    ax.set_ylabel('E[Regret]')
    plt.legend(prop={'size': 8})

plt.savefig("bernoulli.pdf")

# %%
K = 10

# prior 
mu_p = 0.5
sigma_p = 1
sigma_n = 0.1


arm_factory = GaussianArm.factory(mu_p, sigma_p, sigma_n)
arms = [arm_factory() for i in range(K)]
arm_means = [arm.mu for arm in arms]
bandit = BaseStochasticBandit(arms)
# Out:
# Multi-Armed Bandit Problem
#  K=10
#  mu_star = 1.9786404917926872
#  a_star  = 6
#
# Gaussian Arm mu 0.7204653691372837, sigma 0.1.
# Posterior is 0.5, 1
#
# Gaussian Arm mu -0.03290664993766301, sigma 0.1.
# Posterior is 0.5, 1
#
# Gaussian Arm mu -0.3962852494338366, sigma 0.1.
# Posterior is 0.5, 1
#
# Gaussian Arm mu 0.11678566457111156, sigma 0.1.
# Posterior is 0.5, 1
#
# Gaussian Arm mu -1.2994326490638242, sigma 0.1.
# Posterior is 0.5, 1
#
# Gaussian Arm mu 0.979683298153764, sigma 0.1.
# Posterior is 0.5, 1
#
# Gaussian Arm mu 1.9786404917926872, sigma 0.1.
# Posterior is 0.5, 1
#
# Gaussian Arm mu -0.14984403924677703, sigma 0.1.
# Posterior is 0.5, 1
#
# Gaussian Arm mu 0.7288559373381034, sigma 0.1.
# Posterior is 0.5, 1
#
# Gaussian Arm mu -0.02246758640330626, sigma 0.1.
# Posterior is 0.5, 1

# %%
N_seeds = 7
T = 10000

agent_classes = [Thompson, Thompson, Thompson, UCB, lambda x, y: ExploreExploit(x, 1, y, opt=True), lambda x, y: OptimalEpsGreedy(x, 0.01, T)]
agent_names = ["Thompson Correct Prior", "Thompson Wrong Prior A", "Thompson Wrong Prior B", "UCB", "Explore-First", "$\epsilon$-Greedy"]
agent_mats = [np.zeros((N_seeds, T+1)) for i in range(len(agent_classes))]

def run_agent(agent):
    crs = []

    while not agent.terminated():
        reward, cum_reward, a_t = agent.step()
        crs.append(cum_reward)
    
    return np.array(crs)


for i, agent_class in enumerate(agent_classes):
    for seed in range(N_seeds):
        for arm in bandit.arms:
            if agent_names[i] == "Thompson Wrong Prior A":
                arm.prior_mu = 1
                arm.prior_sigma = 0.25
            elif agent_names[i] == "Thompson Wrong Prior B":
                arm.prior_mu = -1
                arm.prior_sigma = 0.25
            else:
                arm.prior_mu = mu_p
                arm.prior_sigma = sigma_p
    
        bandit.reset(False)
        agent = agent_class(bandit, T)
        agent_mats[i][seed, :] = run_agent(agent)

# %%
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
sns.regplot(x = np.arange(1, K+1), y=sorted(arm_means), fit_reg=False)
plt.xlabel("Arm Index");
plt.ylabel("$\mu_i$");

plt.subplot(1, 2, 2)
xs = np.arange(0, T+1)
colors = ['b','y', 'm', 'r', 'g', 'k']
ax = plt.gca()

for indx, agent_mat in enumerate(agent_mats):
    r_mat = agent_mats[indx]
    mu = np.mean(r_mat, axis=0)
    std = np.std(r_mat, axis=0)
    
    plt.fill_between(xs, mu - std, mu + std, alpha=0.25, color = colors[indx])
    plt.plot(mu, color = colors[indx], label=f"{agent_names[indx]}")
    ax.set_yscale('log')
    ax.set_xscale('log')
    ax.set_xlabel('Rounds')
    ax.set_ylabel('E[Regret]')
    plt.legend(prop={'size': 8})
    
plt.savefig("gaussian.pdf")
